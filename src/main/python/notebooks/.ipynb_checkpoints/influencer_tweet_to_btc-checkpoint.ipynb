# %%
import csv
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
os.getcwd()
# Out:
# '/Users/eshuchatowitz/Documents/predictive_analytics/final/twitter-analysis/src/main/python/notebooks'

# %%
def crosscorr(datax, datay, lag=0):
#     " Lag-N cross correlation."
#     Parameters
#     ----------
#     lag : int, default 0
#     datax, datay : pandas.Series objects of equal length

#     Returns
#     ----------
#     crosscorr : float
#     “”"
    return datax.corr(datay.shift(lag))

# %%
bitcoin_df = pd.read_csv("../../resources/raw_data/GOOD_BTC_RAW.csv", ",")

# %%
sentiment_df = pd.read_csv("../../resources/influencer_tweet_sentiment_by_hour.csv")

# %%
sentiment_df.to_csv("../../resources/revised/revised_influencer_sentiment.csv", ",")

# %%
sentiment_df = pd.read_csv("../../resources/revised/revised_influencer_sentiment.csv", ",")

# %%
influencer_sent_to_btc = np.zeros(500)
for x in range(500):
    influencer_sent_to_btc[x] = crosscorr(sentiment_df["LogDiffSent"], bitcoin_df["Close"], -1 * x)

# %%
plt.plot(influencer_sent_to_btc)

# %%
os.chdir("../../resources/sliding_window_influencer_csvs")
for file in glob.glob("*.csv"):
    file_df = pd.read_csv(file)
    maxIter = 0
    maxCorr = 0
    sent_to_btc = np.zeros(30)
    for x in range(30):
        corr = crosscorr(file_df["Sentiment"], file_df["Close"], -1 * x)
        sent_to_btc[x] = corr
        if(corr > maxCorr):
            maxCorr = corr
            maxIter = x
    print(str(file) + "," + str(maxCorr) + "," + str(maxIter))
# Out:
# 2018-10-15T00:00:00Z.csv,0.9552641098847745,0
# 2018-10-15T01:00:00Z.csv,0.9455899000881997,0
# 2018-10-15T02:00:00Z.csv,0.9288363732965028,0
# 2018-10-15T03:00:00Z.csv,0.8939886954937589,0
# 2018-10-15T04:00:00Z.csv,0.8128259317182955,0
# 2018-10-15T05:00:00Z.csv,0.49102861841612766,24
# 2018-10-15T06:00:00Z.csv,0.37839062705260323,7
# 2018-10-15T07:00:00Z.csv,0.4462878951482332,19
# 2018-10-15T08:00:00Z.csv,0.4464066601317358,19
# 2018-10-15T09:00:00Z.csv,0.45277665936198097,19
# 2018-10-15T10:00:00Z.csv,0.48842250849757246,7
# 2018-10-15T11:00:00Z.csv,0.5287488865201915,7
# 2018-10-15T12:00:00Z.csv,0.43792995793680445,7
# 2018-10-15T13:00:00Z.csv,0.47062091979143295,25
# 2018-10-15T14:00:00Z.csv,0.46907032334872056,25
# 2018-10-15T15:00:00Z.csv,0.4728680968230146,25
# 2018-10-15T16:00:00Z.csv,0.47383086224690024,25
# 2018-10-15T17:00:00Z.csv,0.4924027473678597,25
# 2018-10-15T18:00:00Z.csv,0.4853538986636376,25
# 2018-10-15T19:00:00Z.csv,0.4575381332058799,25
# ...
